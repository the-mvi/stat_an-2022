# %% [markdown]
# # Практическая работа №2: Корреляционный и регрессионный анализ.
# Выполнил студент гр. 0373 Логунко Матвей. Вариант №12

# %% [markdown]
# ## Цель работы
# Освоение основных понятий, связанных с корреляционной зависимостью между случайными величинами, статистическими гипотезами и проверкой их «справедливости». Ознакомление с основными положениями метода наименьших квадратов (МНК), со статистическими свойствами МНК оценок, с понятием функции регрессии и роли МНК в регрессионном анализе, с корреляционным отношением, как мерой тесноты произвольной (в том числе и линейной) корреляционной связи.

# %% [markdown]
# ## Основные теоретические положения
# Функциональная зависимость - зависимость, когда каждому значению одной переменной соответствует вполне определённое единственное значение другой.
#
# Статистическая зависимость - зависимость, при которой изменение одной из величин влечёт изменение распределения другой.
#
# Корреляционная зависимость - статистическая зависимость, при которой изменение одной величины приводит к изменению среднего значения другой.
#
# Условное (групповое) среднее - среднее арифметическое тех значений случайной величины X(Y), которые соответствуют значению случайной величины Y=y (X=x):
#
# $\overline{x_{y}}=\frac{\sum_{i=1}^{k_{x}}x_{i}n_{x_{i}y}}{\sum_{i=1}^{k_{x}}n_{x_{i}y}}, \overline{y_{x}}=\frac{\sum_{j=1}^{k_{y}}y_{j}n_{xy_{j}}}{\sum_{j=1}^{k_{y}}n_{xy_{j}}}$
#
# Межгрупповое среднее:
#
# $\overline{xy}=\frac{1}{n}\sum_{i=1}^{k_{x}}\sum_{j=1}^{k_{y}}n_{x_{i}y_{j}}x_{i}y_{j}$
#
# Уравнение регрессии : $\overline{y_{x}}-\overline{y}=r_{yx}\frac{\sigma_{y}}{\sigma_{x}}(x-\overline{x}), \overline{x_{y}}-\overline{x}=r_{xy}\frac{\sigma_{x}}{\sigma_{y}}(y-\overline{y})$
#
# Метод наименьших квадратов:
#
# $\bullet$ основан на минимизации суммы квадратов отклонений некоторых функций от искомых переменных
#
# $\bullet$ Минимизирующая функция: $F(a_{1}\cdots{a_{m}})=\sum_{i=1}^{n}(y_{i}-f(x_{i};a_{1}\cdots{a_{m}})^{2}\rightarrow{min}$
#
# $\bullet$ Необходимое условие экстремума функции многих переменных - равенство нулю всех частных производных функции F
#
# Статистическая оценка коэффициента корреляции:
#
# $r_{B}=\frac{\mu_{xy}}{s_{x}s_{y}}$, где $\mu_{xy}=\overline{xy}-\overline{x} \overline{y}$
#
# Свойства коэффициента корреляции:
#
# $\bullet$ $|r_{xy}|\leq{1}$
#
# $\bullet$ Знак $r_{xy}$ означает, увеличивается ли одна переменная по мере увеличения другой или уменьшается ли одна переменная по мере увеличения другой
#
# $\bullet$ $[r_{xy}]=1$
#
# $\bullet$ Величина $r_{xy}$ обоснована только в диапазоне значений x и y в выборке
#
# $\bullet$ $r_{xy}=r_{yx}$
#
# $\bullet$ Корреляция между x и y не обязательно означает соотношение причины и следствия
#
# $\bullet$ $r_{xy}=0$: нет линейной зависимости зависимости у переменных
#
#
# Через условные варианты:
#
# $r_{B}=\frac{\frac{1}{n}\sum_{i=1}^{k_{u}}\sum_{j=1}^{k_{v}}n_{uv}u_{i}v_{j}-\overline{u} \overline{v}}{\sigma_{u}\sigma_{v}}$, где $u_{i}=\frac{x_{i}-C_{x}}{h_{x}}, v_{j}=\frac{y_{j}-C_{y}}{h_{y}}$
#
# Выборочное корреляционное отношение Y к X - отношение межгруппового СКО к общему СКО признака Y:
#
# $\eta_{yx}=\frac{\sigma_{megr}}{\sigma_{ob}}$. Другое обозначение: $\eta_{yx}=\frac{\sigma_{\overline{y_{x}}}}{\sigma_{y}}$, где $\sigma_{\overline{y_{x}}}=\sqrt{\sigma_{mezhgr}^{2}}=\sqrt{\frac{(\sum{n_{x}(\overline{y_{x}}-\overline{y})^{2}})}{n}}, \sigma_{\overline{y}}=\sqrt{\sigma_{obsch}^{2}}=\sqrt{\frac{(\sum{n_{y}(\overline{y_{x}}-\overline{y})^{2}})}{n}}$
#
# Свойства корреляционного отношения:
#
# $\bullet$ $\eta\in[0,1] $
#
# $\bullet$ Если $\eta=0$, то признак Y с признаком X корреляционной зависимостью не связан (справедливо и обратное)
#
# $\bullet$ Если $\eta=1$, то признак Y связан с признаком X функциональной зависимостью (справедливо и обратное)
#
# $\bullet$ $\eta\geq|r_{B}| $
#
# $\bullet$ Если $\eta=r_{B}$, то имеет место быть точная линейная корреляционная зависимость
#
#
# Доверительный интервал для оценки выборочного коэффициента корреляции:
#
# $(th(z-\frac{t}{\sqrt{n-3}});th(z+\frac{t}{\sqrt{n-3}}))$, где t определяется как $\Phi(t)=\frac{\gamma}{2}$
#
# Преобразование Фишера:
#
# $z=arth(r_{B}) $
#
# $T_{nabl}=r_{B}\frac{\sqrt{n-2}}{\sqrt{1-r_{B}^{2}}}$
#
# $T_{krit}=t(\alpha,df)$, где $df=n-2$
#
# Теорема о разложении дисперсии:
#
# $\sigma^{2}=(\delta^{*})^{2}+(\varepsilon^{*})^{2} $
#
# Дисперсия результативного признака:
#
# $(\delta_{y}^{*})^{2}=\frac{1}{n}\sum_{i=1}^{n}(y_{x_{i}}-\overline{y})^{2}, (\delta_{x}^{*})^{2}=\frac{1}{n}\sum_{i=1}^{n}(x_{y_{i}}-\overline{x})^{2} $
#
# Необъяснённая уравнением регрессии дисперсия результативного признака (остаточная дисперсия):
#
# $(\varepsilon_{y}^{*})^{2}=\frac{1}{n}\sum_{i=1}^{n}\varepsilon_{y_{i}}^{2},  (\varepsilon_{x}^{*})^{2}=\frac{1}{n}\sum_{i=1}^{n}\varepsilon_{x_{i}}^{2}$
#
# Теоретический коэффициент детерминации - отношение оъяснённой (уравнением) дисперсии признака-результата к общей дисперсии результативного признака:
#
# $R_{y}^{2}=\frac{(\delta_{y}^{*})^{2}}{\sigma_{y}^{2}}, R_{x}^{2}=\frac{(\delta_{x}^{*})^{2}}{\sigma_{x}^{2}} $
#
# Средняя квадратичная ошибка уравнения регрессии - среднее квадратичное отклонение наблюдаемых значений результативного признака от теоритических значений, рассчитанных по модели:
#
# $S_{\varepsilon_{y}}=\sqrt{\frac{1}{n-l}\sum_{i=1}^{n}\varepsilon_{y_{i}}^{2}}, S_{\varepsilon_{x}}=\sqrt{\frac{1}{n-l}\sum_{i=1}^{n}\varepsilon_{x_{i}}^{2}}$, где l - количество параметров в модели регрессии
#
# Средняя ошибка аппроксимации:
#
# $A_{y}=\frac{1}{n}\sum_{i=1}^{n}|\frac{\varepsilon_{y_{i}}}{y_{i}}|, A_{x}=\frac{1}{n}\sum_{i=1}^{n}|\frac{\varepsilon_{x_{i}}}{x_{i}}|$

# %% [markdown]
# ## Постановка задачи
# Из заданной генеральной совокупности сформировать выборку по второму признаку. Для системы двух случайных величин X (первый признак) и Y (второй признак) сформировать двумерную выборку и найти статистическую оценку коэффициента корреляции, построить доверительный интервал для коэффициента корреляции и осуществить проверку статистической гипотезы о равенстве коэффициента корреляции нулю. Построить уравнения выборочных прямых среднеквадратической регрессии. Полученные линейные функции регрессии отобразить графически. Найти выборочное корреляционное отношение. Оценить адекватность моделей. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Возьмем из прошлой работы вычисления для Х

# %%
import pandas as pd
## объем выборки
n=102
# s - выборка
s = pd.Series([124.75166,
118.675,
121.99166,
128.01683,
126.8965,
143.60483,
152.6685,
177.71166,
201.33316,
188.3985,
198.79333,
201.24116,
248.32116,
343.67975,
339.795,
415.93975,
512.16999,
580.11375,
823.41525,
904.585,
1157.49894,
1049.67916,
1144.36916,
845.85092,
975.62383,
897.30915,
757.02366,
733.23666,
685.3675,
780.93666,
759.6362,
774.26333,
873.98,
970.22516,
902.035,
873.27168,
879.62999,
885.16166,
874.13266,
876.24165,
860.24269,
852.3975,
856.03366,
815.79724,
711.97109,
671.9975,
657.99749,
641.37249,
581.24,
583.135,
583.7825,
568.275,
666.3275,
626.25,
645.75,
636.75668,
630.77666,
604.52831,
570.33081,
589.95497,
504.21231,
500.64066,
455.99333,
458.925,
427.5385,
425.68516,
543.31749,
511.76836,
498.59166,
472.48499,
445.73085,
459.42666,
438.44883,
446.35999,
453.54333,
439.51833,
447.15166,
458.23333,
535.09,
589.945,
576.55666,
638.94666,
675.73833,
657.94166,
653.34666,
633.66166,
593.54833,
612.85666,
603.205,
588.78,
600.72,
647.12249,
646.88375,
632.575,
624.01,
635.04625,
622.46124,
628.54499,
622.20624,
618.26374,
595.87875,
581.28125])
print("Выборка")
print(s)
import numpy as np
import math as math
## ранжированный ряд  

print("Вывод ранжированного ряда")
print(s.sort_values(ascending=True,ignore_index=True))
# x - вариационный ряд  
x=s.value_counts().reset_index()
x.columns=["number","frequency"]
x=x.sort_values(by=['number']).reset_index(drop=True)
print(x)
from math import ceil
from math import floor
from math import log2
## формула Стёрджеса  
k = ceil(1+log2(n))
## интервальный ряд 
s1=s.value_counts(normalize=False,bins=k,sort=False).to_frame().reset_index()
s1.columns=["int","freq"]
print("Вывод интервального ряда")
print(s1)
## разница между макс и мин значениями выборки
r=s.max()-s.min()
## длина интервала(шаг) 
h=r/k
##абс частота интервалов 
c = [0]*k
## отн частота интервалов 
c1 = [0]*k
j = 0
for i in s.value_counts(bins=8,sort=False):
    c[j] = i
    c1[j] = i/n
    j += 1
 ## концы интервалов
start= [0]*(k+1)
start[0]=s.min()
for i in range(1,k+1):
    start[i]=start[i-1]+h
## среднее значение интервала
mid_range=[0]*(k)
for i in range(1,k+1):
    mid_range[i-1]=start[i]-h/2
## накопленные абсолютные частоты 
m=[0]*(k)
## накопленные отностельные частоты 
m1=[0]*(k)
for i in range(0,k):
    m1[i]=(m1[i-1]+c[i]) 
for i in range(0,k):
    m1[i]=m1[i]/n 
for i in range(0,k):
    m[i]=(m[i-1]+c[i])
bin_dt, bin_gr = np.histogram(start, bins=len(c))
t = pd.DataFrame(columns=["(x(i-1);x(i)]","xср(i)","n(i)","p*(i)","sum(n(i))","sum(p*(i))"])
t["(x(i-1);x(i)]"]=s1["int"]
t["xср(i)"]=mid_range
t["n(i)"]=s1["freq"]
t["p*(i)"]=c1
t["sum(n(i))"]=m
t["sum(p*(i))"]=m1
t.loc["sum"]=["-","-",np.sum(t["n(i)"]),np.sum(t["p*(i)"]),"-","-"]
## номер ложного нуля
C=((len(c)-1)/2)
C=math.floor(C) if s1["freq"][math.floor(C)] > s1["freq"][math.ceil(C)] else math.ceil(C)
## условные варианты 
U =[]
t2 = pd.DataFrame(columns=["x(i)","n(i)","u(i)","n(i)u(i)","n(i)u^2(i)","n(i)u^3(i)","n(i)u^4(i)","n(i)(u(i)+1)^4"])
for i in range (len(c)):
    U.append((t["xср(i)"][i]-t["xср(i)"][C])/h)
n_u_1 = []
n_u_2 = []
n_u_3 = []
n_u_4 = []
n_u_plus = []
for i in range(len(U)):
    n_u_1.append(t["n(i)"][i]*U[i])
    n_u_2.append(t["n(i)"][i]*U[i]**2)
    n_u_3.append(t["n(i)"][i]*U[i]**3)
    n_u_4.append(t["n(i)"][i]*U[i]**4)
    n_u_plus.append(round(t["n(i)"][i]*(U[i]+1)**4,1))
t2["x(i)"]=t["xср(i)"][:len(t)-1]                     
t2["n(i)"]=t["n(i)"]    
t2["u(i)"]=U 
t2["n(i)u(i)"]=n_u_1 
t2["n(i)u^2(i)"]=n_u_2 
t2["n(i)u^3(i)"]=n_u_3  
t2["n(i)u^4(i)"]=n_u_4  
t2["n(i)(u(i)+1)^4"]=n_u_plus 
t2.loc["sum"]=["-",np.sum(t2["n(i)"]),"-",np.sum(t2["n(i)u(i)"]),np.sum(t2["n(i)u^2(i)"]),np.sum(t2["n(i)u^3(i)"]),np.sum(t2["n(i)u^4(i)"]),np.sum(t2["n(i)(u(i)+1)^4"])]
## условные эмпирические моменты
V = []
## порядок
r = 4
for i in range(r):
    V.append(1/n*t2.loc["sum"][i+3])
## центральные эмпирические моменты
V1 =[0]*(r)
V1[0]=0
V1[1]=((V[1]-V[0]**2)*h**2)
V1[2]=(V[2]-3*V[1]*V[0]+2*V[0]**3)*h**3
V1[3]=(V[3]-4*V[2]*V[0]+6*V[1]*V[0]-3*V[0]**4)*h**4
t3=pd.DataFrame(columns=["v*(i)","и*(i)"], index=range(1,r+1))
t3["v*(i)"]=V
t3["и*(i)"]=V1
## сумма среднеинтвервальных значений 
ss=0
for i in range(k):
    ss=t2["x(i)"][i]+ss
## среднее выборочное 
xB= ss/k
## среднее с помощью условных вариант
xB_=h*t3["v*(i)"][1]+t["xср(i)"][C]
print("Cреднее выборочное по стандартным формулам",xB)
print("Cреднее выборочное  по условным ",xB_)
xB
## диспересия 
d=0
for i in range (n):
    d=d+(s[i]-xB)**2
d=d/n
## диспересия по условным 
D_=t3["и*(i)"][2]
print("Дисперсия по стандартным формулам=",d)
print("Дисперсия по условным вариантам =",D_)
sko=math.sqrt(d)
d_new=n/(n-1)*d
sko_new=math.sqrt(d_new)
print("Дисперсия =",d)
print("Исправленная выборочная дисперсия=",d_new)
print("Отношение дисперсий =",d_new/d)
print("СКО =",sko)
print("Исправленное СКО",sko_new)
print("Отношение CKO =",sko_new/sko)
# Out:
# Выборка
# 0      124.75166
# 1      118.67500
# 2      121.99166
# 3      128.01683
# 4      126.89650
#          ...
# 97     628.54499
# 98     622.20624
# 99     618.26374
# 100    595.87875
# 101    581.28125
# Length: 102, dtype: float64
# Вывод ранжированного ряда
# 0       118.67500
# 1       121.99166
# 2       124.75166
# 3       126.89650
# 4       128.01683
#           ...
# 97      970.22516
# 98      975.62383
# 99     1049.67916
# 100    1144.36916
# 101    1157.49894
# Length: 102, dtype: float64
#          number  frequency
# 0     118.67500          1
# 1     121.99166          1
# 2     124.75166          1
# 3     126.89650          1
# 4     128.01683          1
# ..          ...        ...
# 97    970.22516          1
# 98    975.62383          1
# 99   1049.67916          1
# 100  1144.36916          1
# 101  1157.49894          1
#
# [102 rows x 2 columns]
# Вывод интервального ряда
#                              int  freq
# ...

# %% [markdown]
# # Задание 1
# Провести статистическую обработку второй выборки в объеме практической работы №1 с целью определения точечных статистических
# оценок параметров распределения исследуемого признака (математического ожидания, дисперсии, среднеквадратичного отклонения,
# асимметрии, эксцесса, моды, медианы и коэффициента вариации).

# %%
import pandas as pd
## объем выборки
n=102
# s - выборка
sY = pd.Series([122.56349,
107.05816,
120.43199,
123.81966,
125.2765,
132.94933,
142.47949,
163.87149,
158.72216,
174.9035,
192.83366,
198.71016,
221.84833,
293.48749,
303.6505,
383.5775,
436.13324,
428.9815,
691.6925,
787.19,
1028.22683,
929.95483,
870.3838,
682.71342,
832.22683,
848.25583,
647.62209,
598.06131,
632.5431,
698.07,
713.751,
750.52516,
808.71666,
788.70166,
837.57458,
821.00333,
841.27916,
834.77499,
854.05916,
833.72638,
798.18333,
839.53166,
842.73749,
738.61499,
662.74428,
633.395,
626.80499,
607.9425,
538.12249,
492.8925,
558.2225,
550.74749,
643.525,
600.99249,
615.2725,
624.77166,
616.17333,
579.55331,
551.16331,
561.61165,
483.5116,
459.6783,
428.63,
443.71861,
344.22166,
394.1018,
493.08333,
467.81668,
482.73666,
440.13883,
421.07659,
447.27006,
428.51836,
423.11181,
446.21333,
433.13333,
442.29,
442.05333,
487.815,
533.13,
560.415,
610.82499,
617.78666,
635.85166,
637.57833,
562.59,
551.31,
599.72333,
581.68666,
570.47166,
576.24833,
597.04499,
635.26625,
627.43125,
616.165,
625.99249,
617.84124,
616.475,
616.73375,
591.455,
579.15125,
559.62249])
print("Выборка")
print(sY)
# Out:
# Выборка
# 0      122.56349
# 1      107.05816
# 2      120.43199
# 3      123.81966
# 4      125.27650
#          ...
# 97     616.47500
# 98     616.73375
# 99     591.45500
# 100    579.15125
# 101    559.62249
# Length: 102, dtype: float64

# %%
import numpy as np
import math as math
from math import ceil
from math import floor
from math import log2
## формула Стёрджеса  
k = ceil(1+log2(n))
## интервальный ряд 
s1Y=sY.value_counts(normalize=False,bins=k,sort=False).to_frame().reset_index()
s1Y.columns=["int","freq"]
## разница между макс и мин значениями выборки
rY=sY.max()-sY.min()
## длина интервала(шаг) 
hY=rY/k
##абс частота интервалов 
cY = [0]*k
## отн частота интервалов 
c1Y = [0]*k
j = 0
for i in sY.value_counts(bins=8,sort=False):
    cY[j] = i
    c1Y[j] = i/n
    j += 1
## концы интервалов
startY= [0]*(k+1)
startY[0]=sY.min()
for i in range(1,k+1):
    startY[i]=startY[i-1]+hY
## среднее значение интервала
mid_rangeY=[0]*(k)
for i in range(1,k+1):
    mid_rangeY[i-1]=startY[i]-hY/2
mid_rangeY
## накопленные абсолютные частоты 
mY=[0]*(k)
for i in range(0,k):
    mY[i]=(mY[i-1]+cY[i])
## накопленные отностельные частоты 
m1Y=[0]*(k)
for i in range(0,k):
    m1Y[i]=(m1Y[i-1]+cY[i]) 
for i in range(0,k):
    m1Y[i]=m1Y[i]/n 
xY=sY.value_counts().reset_index()
xY.columns=["number","frequency"]
xY=xY.sort_values(by=['number']).reset_index(drop=True)

## номер ложного нуля
CY=((len(cY)-1)/2)
CY=math.floor(CY) if s1Y["freq"][math.floor(CY)] > s1Y["freq"][math.ceil(CY)] else math.ceil(CY)
## условные варианты 
UY =[]
t2Y = pd.DataFrame(columns=["y(i)","n(i)","u(i)","n(i)u(i)","n(i)u^2(i)","n(i)u^3(i)","n(i)u^4(i)","n(i)(u(i)+1)^4"])
for i in range (len(cY)):
    UY.append((tY["yср(i)"][i]-tY["yср(i)"][CY])/hY)
n_u_1Y = []
n_u_2Y = []
n_u_3Y = []
n_u_4Y = []
n_u_plusY = []
for i in range(len(UY)):
    n_u_1Y.append(tY["n(i)"][i]*UY[i])
    n_u_2Y.append(tY["n(i)"][i]*UY[i]**2)
    n_u_3Y.append(tY["n(i)"][i]*UY[i]**3)
    n_u_4Y.append(tY["n(i)"][i]*UY[i]**4)
    n_u_plusY.append(round(tY["n(i)"][i]*(UY[i]+1)**4,1))
t2Y["y(i)"]=tY["yср(i)"][:len(t)-1]                     
t2Y["n(i)"]=tY["n(i)"]    
t2Y["u(i)"]=UY 
t2Y["n(i)u(i)"]=n_u_1Y 
t2Y["n(i)u^2(i)"]=n_u_2Y 
t2Y["n(i)u^3(i)"]=n_u_3Y  
t2Y["n(i)u^4(i)"]=n_u_4Y  
t2Y["n(i)(u(i)+1)^4"]=n_u_plusY 
t2Y.loc["sum"]=["-",np.sum(t2Y["n(i)"]),"-",np.sum(t2Y["n(i)u(i)"]),np.sum(t2Y["n(i)u^2(i)"]),np.sum(t2Y["n(i)u^3(i)"]),np.sum(t2Y["n(i)u^4(i)"]),np.sum(t2Y["n(i)(u(i)+1)^4"])]
## условные эмпирические моменты
VY = []
## порядок
r = 4
for i in range(r):
    VY.append(1/n*t2Y.loc["sum"][i+3])
## центральные эмпирические моменты
V1Y =[0]*(r)
V1Y[0]=0
V1Y[1]=((VY[1]-VY[0]**2)*hY**2)
V1Y[2]=(VY[2]-3*VY[1]*VY[0]+2*VY[0]**3)*hY**3
V1Y[3]=(VY[3]-4*VY[2]*VY[0]+6*VY[1]*VY[0]-3*VY[0]**4)*hY**4
t3Y=pd.DataFrame(columns=["v*(i)","и*(i)"], index=range(1,r+1))
t3Y["v*(i)"]=VY
t3Y["и*(i)"]=V1Y
## сумма среднеинтвервальных значений 
ssY=0
for i in range(k):
    ssY=t2Y["y(i)"][i]+ssY
## среднее выборочное 
xBY= ssY/k
xB_Y=hY*t3Y["v*(i)"][1]+tY["yср(i)"][CY]
print("Cреднее выборочное  по условным ",xB_Y)
print("Cреднее выборочное по стандартным формулам",xBY)
## диспересия 
dY=0
for i in range (n):
    dY=dY+(sY[i]-xBY)**2
dY=dY/n
print("Дисперсия по стандартным формулам=",dY)
skoY=math.sqrt(dY)
d_newY=n/(n-1)*dY
sko_newY=math.sqrt(d_newY)
print("Исправленная выборочная дисперсия=",d_newY)
print("СКО =",skoY)
print("Исправленное СКО",sko_newY)
asymmetryY=t3Y["и*(i)"][3]/(skoY)**3
excessY=t3Y["и*(i)"][4]/(skoY)**4-3
print("коэффициент асимметрии",asymmetryY)
print("коэффициент эксцесса",excessY)
max_frequencyY=np.max(s1Y["freq"])
moda_Y=[]
indexY=[]
medianaY=0
index1Y = 0
for i in range(len(s1Y)):
    if (s1Y["freq"][i] ==max_frequencyY):
        moda_Y=s1Y["int"][i].left
        indexY=i
##мода показывает на локальный максимум распределения
modaY=moda_Y+hY*((s1Y["freq"][indexY]-s1Y["freq"][indexY-1]))/((s1Y["freq"][indexY]-s1Y["freq"][indexY-1])+(s1Y["freq"][indexY]-s1Y["freq"][indexY+1]))
while (tY["sum(n(i))"][index1Y] < tY["sum(n(i))"][len(s1Y)-1]/2):
    index1Y += 1
mediana_Y = s1Y["int"][index1Y].left
##медиана показывает на точку делящую распределение на две равновероятностные половины
medianaY = mediana_Y + hY/(tY["p*(i)"])[index1Y]*(0.5 - tY["sum(p*(i))"][index1Y-1])
## коэффициент вариации показывает степень изменчивости по отношению к среднему показателю
kf_varY =skoY/abs(xBY)*100
print("Мода = ", modaY)
print("Медиана = " , medianaY)
print("Коэффициент вариации = " , kf_varY,"%")
# Out:
# Cреднее выборочное  по условным  548.4514810416666
# Cреднее выборочное по стандартным формулам 567.642495
# Дисперсия по стандартным формулам= 43010.808288029315
# Исправленная выборочная дисперсия= 43436.657875039506
# СКО = 207.3904729924432
# Исправленное СКО 208.4146297049214
# коэффициент асимметрии -0.2658630319007876
# коэффициент эксцесса -2.7817926355873457
# Мода =  610.82178140625
# Медиана =  578.4369453515626
# Коэффициент вариации =  36.535402972683215 %

# %%
tY = pd.DataFrame(columns=["(y(i-1);y(i)]","yср(i)","n(i)","p*(i)","sum(n(i))","sum(p*(i))"])
tY["(y(i-1);y(i)]"]=s1Y["int"]
tY["yср(i)"]=mid_rangeY
tY["n(i)"]=s1Y["freq"]
tY["p*(i)"]=c1Y
tY["sum(n(i))"]=mY
tY["sum(p*(i))"]=m1Y
tY.loc["sum"]=["-","-",np.sum(tY["n(i)"]),np.sum(tY["p*(i)"]),"-","-"]
tY
# Out:
#            (y(i-1);y(i)]      yср(i)  n(i)     p*(i) sum(n(i)) sum(p*(i))
# 0     (106.136, 222.204]  164.631202    13  0.127451        13   0.127451
# 1      (222.204, 337.35]  279.777286     2  0.019608        15   0.147059
# 2      (337.35, 452.496]  394.923369    16  0.156863        31   0.303922
# 3     (452.496, 567.642]  510.069453    17  0.166667        48   0.470588
# 4     (567.642, 682.789]  625.215537    32  0.313725        80   0.784314
# 5     (682.789, 797.935]  740.361621     7  0.068627        87   0.852941
# 6     (797.935, 913.081]  855.507704    13  0.127451       100   0.980392
# 7    (913.081, 1028.227]  970.653788     2  0.019608       102        1.0
# sum                    -           -   102  1.000000         -          -

# %%
table_characteristics = pd.DataFrame(columns=["Характеристика", "y_B", "sigma^2", "s^2", "s", "e", "Moda", "Mediana", "V"])
table_characteristics.loc[0] = ["Значение", xBY,dY, d_newY, asymmetryY, excessY, modaY, medianaY,  kf_varY]
table_characteristics
# Out:
#   Характеристика         y_B       sigma^2           s^2         s         e  \
# 0       Значение  567.642495  43010.808288  43436.657875 -0.265863 -2.781793
#
#          Moda     Mediana          V
# 0  610.821781  578.436945  36.535403

# %% [markdown]
# # Выводы
# Разница исправленной выборочной дисперсии со смещёнными оценками дисперсии незначительна.
#
# Коэффициент асимметрии характеризует скошенность распределения относительно самого высокого участка по отношению к математическому ожиданию.
# Эксцесс характеризует подъем кривой теоретического распределения по сравнению с нормальной кривой.
#  Получили отрицательную ассиметрию, значит большая часть кривой расположена слева от математического ожидания.
#  Получили отрицательный эксцесс, значит кривая более плосковершинная.
# По полученному коэффициенту вариации большему 33%, можно сказать что выборка неоднородная.

# %% [markdown]
# # Задание 2
# Построить двумерный интервальный вариационный ряд, оформить
# в виде таблицы

# %%
i=0
j=0
double_array = np.zeros((k,k), dtype=int)
double_array1 = np.zeros((k,k+1), dtype=int)
for i in range(n):
    while s[i] > s1["int"][j].right:
        j+=1
    for l in range(k):
        if sY[i] > s1Y["int"][l].left and sY[i] <= s1Y["int"][l].right:
            double_array[l][j]+=1
            j=0
double_array1
for i in range(k):
    for j in range(k):
        double_array1[i][j+1]=double_array[i][j]
double_array[1][0]
sum_yy = []
sum_xx = []
for i in range(len(double_array)):
    sum_yy.append(sum(double_array[i]))
    sumcounter = 0
    for j in range(len(double_array[i])):
        sumcounter+=double_array[j][i]
    sum_xx.append(sumcounter)

print('Проверка: сумма частот по y = ',sum(sum_yy),'сумма частот по x =', sum(sum_xx))
# Out:
# Проверка: сумма частот по y =  102 сумма частот по x = 102

# %%
columns_names = ['Y/X']
indexes_names = []
for i in range(8):
    columns_names.append(s1["int"][i])
    indexes_names.append(s1Y["int"][i])
double_table = pd.DataFrame(data=double_array1,columns=columns_names)
double_table['Y/X'] = indexes_names
double_table
# Out:
#                    Y/X  (117.63499999999999, 248.528]  (248.528, 378.381]  \
# 0   (106.136, 222.204]                             13                   0
# 1    (222.204, 337.35]                              0                   2
# 2    (337.35, 452.496]                              0                   0
# 3   (452.496, 567.642]                              0                   0
# 4   (567.642, 682.789]                              0                   0
# 5   (682.789, 797.935]                              0                   0
# 6   (797.935, 913.081]                              0                   0
# 7  (913.081, 1028.227]                              0                   0
#
#    (378.381, 508.234]  (508.234, 638.087]  (638.087, 767.94]  \
# 0                   0                   0                  0
# 1                   0                   0                  0
# 2                  14                   2                  0
# ...

# %% [markdown]
# # Вывод
# Вывод: сумма частот появления варианты х и сумма частот появления варианты у совпадает, следовательно, контроль пройден и вычисления верны

# %% [markdown]
# # Задание 3
# По полученному двумерному интервальному вариационному ряду
# сформировать условные варианты и по полученным условным вариантам построить корреляционную таблицу, сделать выводы:

# %%
columns_names = ['V/U']
indexes_names = []
columns_names+=[round(item, 2) for item in U] + ['U', 'vU']
indexes_names+=[round(item, 2) for item in UY] + ['V', 'uV']
table_3 = pd.DataFrame(columns=columns_names)
table_3['V/U'] = indexes_names
for i in range(len(double_array)):
    for j in range(len(double_array[i])):
        table_3.loc[i, columns_names[j+1]] = double_array[i][j]
U_big = []
V_big = []
vU = []
uV = []
for i in range(len(double_array)):
    u_sum = 0
    v_sum = 0
    for j in range(len(double_array[i])):
        u_sum+= U[j] * double_array[i][j]
        v_sum+= UY[j] * double_array[j][i]
    U_big.append(u_sum)
    V_big.append(v_sum)
    vU.append(UY[i] * U_big[-1])
    uV.append(U[i] * V_big[-1])
    table_3.loc[i, 'U'] = U_big[-1]
    table_3.loc[i, 'vU'] = vU[-1]
    table_3.loc[j+1, columns_names[i+1]] = V_big[-1]
    table_3.loc[j+2, columns_names[i+1]] = uV[-1]
table_3.loc[i+1, 'U'] = '-'
table_3.loc[i+1, 'vU'] = np.sum(vU)
table_3.loc[j+2, columns_names[i+2]] = np.sum(vU)
table_3.loc[j+2, 'vU'] = 'Верно' if table_3['U'][len(table_3)-1] == table_3['vU'][len(table_3)-2] else 'Неверно'
table_3
# Out:
#    V/U   -3.0  -2.0  -1.0   0.0  1.0   2.0   3.0   4.0      U     vU
# 0 -4.0     13     0     0     0    0     0     0     0  -39.0  156.0
# 1 -3.0      0     2     0     0    0     0     0     0   -4.0   12.0
# 2 -2.0      0     0    14     2    0     0     0     0  -14.0   28.0
# 3 -1.0      0     0     3    14    0     0     0     0   -3.0    3.0
# 4  0.0      0     0     0    16   15     1     0     0   17.0    0.0
# 5  1.0      0     0     0     0    1     4     2     0   15.0   15.0
# 6  2.0      0     0     0     0    0    10     2     1   30.0   60.0
# 7  3.0      0     0     0     0    0     0     0     2    8.0   24.0
# 8    V  -52.0  -6.0 -31.0 -18.0  1.0  24.0   6.0   8.0      -  298.0
# 9   uV  156.0  12.0  31.0  -0.0  1.0  48.0  18.0  32.0  298.0  Верно

# %% [markdown]
# # Вывод
# Суммы vU и uV равны, следовательно, контроль пройден и вычисления верны

# %% [markdown]
# # Задание 4
# Исходя из результатов корреляционной таблицы вычислить коэффициент корреляции, сделать выводы.

# %%
sum_v = []
sum_u = []
for i in range(len(double_array)):
    sum_v.append(sum(double_array[i]))
    sumcounter = 0
    for j in range(len(double_array[i])):
        sumcounter+=double_array[j][i]
    sum_u.append(sumcounter)
print(sum_v, sum_u) 
v_mid = 0
u_mid = 0
for i in range(k):
    v_mid += UY[i]*sum_v[i]/n
    u_mid += U[i]*sum_u[i]/n
SKO_v = 0
SKO_u = 0
for i in range(k):
    SKO_v += (U[i] - v_mid)**2*sum_v[i]/n
    SKO_u += (UY[i] - u_mid)**2*sum_u[i]/n
SKO_v = SKO_v**0.5
SKO_u = SKO_u**0.5
rv = (sum(vU)/n - v_mid*u_mid)/(SKO_v*SKO_u)
print(rv)
# Out:
# [13, 2, 16, 17, 32, 7, 13, 2] [13, 2, 17, 32, 16, 15, 4, 3]
# 0.7229474875304001

# %% [markdown]
# # Вывод

# %% [markdown]
# Модуль коэффициента корреляции $\leq$ 1, следовательно, вычисления верны. Коэффициент корреляции положителен, значит, с увеличением х увеличивается у

# %% [markdown]
# # Задание 5
# Построить доверительный интервал для коэффициента корреляции при уровне значимости 𝛾 ∈ {0.95, 0.99}, сделать выводы.

# %%
исправитьf_t_1 = 2.56 #99
f_t_2 = 1.96 #95
z = math.atanh(rv)
z_left = z - max(f_t_1, f_t_2)/(n-3)**0.5
z_right = z + max(f_t_1, f_t_2)/(n-3)**0.5
print(f"({z_left}; {z_right})")
# Out:
# (0.6565026666903446; 1.1710820281030614)

# %% [markdown]
# # Вывод

# %% [markdown]
# При уровне значимости 99% доверительный интервал с большей вероятностью покроет искомую величину
# В получившийся доверительный интервал попадает коэффициент корреляции rv=0.7229474875304001.
# Вычисления выполнены верно

# %% [markdown]
# # Задание 6
# Осуществить проверку статистической гипотезы о равенстве коэффициента корреляции нулю при заданном уровне значимости
# 𝛼 = 0.05, сделать выводы.

# %%
T_observable = rv*(n-2)**0.5/(1-rv**2)**0.5
T_crit = 1.984
print('T наблюдаемое = ',T_observable,'T крит = ', T_crit)
if abs(T_observable) < T_crit:
    print('Принимаем гипотезу. Коэффициент корреляции равен нулю.' )
else:
          print('Отвергаем гипотезу. Коэффициент корреляции не равен нулю.')
# Out:
# T наблюдаемое =  10.463806157512954 T крит =  1.984
# Отвергаем гипотезу. Коэффициент корреляции не равен нулю.

# %% [markdown]
# # Задание 7
# Для заданной выборки построить уравнения средней квадратичной
# регрессии 𝑥 на 𝑦 и 𝑦 на 𝑥 соответственно. Отобразить полученные
# прямые на множестве выборки. Объяснить результаты.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot(s, rv*skoY/sko*(s-xB)+xBY,c='b') ## y на x
plt.plot(rv*sko/skoY*(sY-xBY)+xB, sY,c='g')## x на y
plt.scatter(s,sY,c='m')
plt.show()

# %% [markdown]
# # Вывод
# Уравнения средней квадратичной регрессии характеризуются прямыми. Они дают общую характеристику положениям значений на множестве выборки

# %% [markdown]
# # Задание 8
# Вычислить корреляционные отношения 𝜂𝑦𝑥 и 𝜂𝑥𝑦. Убедиться, что
# неравенства 𝜂𝑦𝑥 > |𝑟𝑥𝑦| и 𝜂𝑥𝑦 > |𝑟𝑥𝑦| выполняются. Сделать выводы.

# %%
import math
sko_all=0
sko_y=0
for i in range (k):
    sko_all+=sum_v[i]*(tY["yср(i)"][i]-xBY)**2
sko_all=sko_all/n
sko_y=math.sqrt(sko_all)
sko_y
ttrY=np.zeros(k)
for i in range (k):
    for j in range (k):
        ttrY[i]+=double_array[i][j]*tY["yср(i)"][i]
    ttrY[i]=ttrY[i]/sum_v[i]
sko_y1=0
for i in range (k):
    sko_all1+=sum_v[i]*(ttrY[i]-xBY)**2
sko_all1=sko_all1/n  
sko_y1=sko_all1**0.5
nyx=sko_y1/sko_y
nyx
# Out:
# 1.004938301637971

# %%
sko_all_x=0
sko_x=0
for i in range (k):
    sko_all_x+=sum_u[i]*(t["xср(i)"][i]-xB)**2
sko_all_x=sko_all_x/n
sko_x=math.sqrt(sko_all_x)
sko_x

ttrX=np.zeros(k)
for j in range (k):
    for i in range (k):
        ttrX[j]+=double_array[i][j]*t["xср(i)"][j]
    ttrX[j]=ttrX[j]/sum_u[j]
sko_x1=0

sko_all_x1=0
for i in range (k):
    sko_all_x1+=sum_u[i]*(ttrX[i]-xB)**2
sko_all_x1=sko_all_x1/n  
sko_x1=math.sqrt(sko_all_x1)
nxy=sko_x1/sko_x
nxy
# Out:
# 1.0

# %% [markdown]
# Вывод: условие $\eta\in[0,1] $ и неравенство $\eta\geq|r_{B}| $ выполняются,тк rv=0.7229474875304001, следовательно, вычисления верны. Также корреляционные отношения равны 1, что свидетельствует о связи признака Y с признаком X функциональной зависимостью и наоборот

# %% [markdown]
# # Задание 9
# Для заданной выборки построить корреляционную кривую параболического вида 𝑦 = 𝛽0+𝛽1𝑥+𝛽2𝑥
# 2
# . Отобразить полученную кривую
# на множестве выборки. Сделать выводы.

# %%
SUM1x=sum(s)
SUM2x=sum(np.array(s)**2)
SUM3x=sum(np.array(s)**3)
SUM4x=sum(np.array(s)**4)
SUM5y=sum(sY)
SUM6xy=sum(np.array(s)*np.array(sY))
SUM7xy=sum(np.array(s)**2*np.array(sY))

# %%
B = np.linalg.solve(np.array([[n,SUM1x,SUM2x],[SUM1x,SUM2x,SUM3x],[SUM2x,SUM3x,SUM4x]]), np.array([SUM5y,SUM6xy,SUM7xy]))
plt.figure(figsize=(8,8))
plt.plot(s, B[2]*(np.array(s)**2)+B[1]*s+B[0],c='b')
plt.scatter(s,sY,c='m')
plt.show()

# %% [markdown]
# # Вывод
# Уравнение параболической регрессии имеет вид: $y = -0.00021x^{2} + 1.125917x -32.361862$.
# График отображает средние значения на множестве выборки

# %% [markdown]
# # Задание 10
# Для заданной выборки построить нелинейные корреляционные кривые c помощью МНК в зависимости от номера варианта:  дробно-рациональная функция

# %%
SUM_1=sum(1/np.array(s))
SUM_2=sum(1/np.array(s)**2)
SUM_3=sum(1/np.array(sY))
SUM_4=sum(1/(np.array(s)*np.array(sY)))
B_2 = np.linalg.solve(np.array([[n,SUM_1],[SUM_1,SUM_2]]), np.array([SUM_3,SUM_4]))
plt.figure(figsize=(8,8))
plt.plot(s,s/(B_2[0]*s+B_2[1]),c='b')
plt.scatter(s,sY,c='m')
plt.show()

# %% [markdown]
# # Вывод
# Уравнение: $y=\frac{x}{0.000041x+1.052909}$
# График отображает средние значения на множестве выборки

# %% [markdown]
# # Задание 11
# Вычислить следующие показатели качества регрессии для каждого
# из четырёх уравнений и сделать выводы:
# • теоретический коэффициент детерминации 𝑅2
# • средняя квадратическая ошибка 𝑆𝜀;
# • средняя ошибка аппроксимации (приближения)

# %% [markdown]
# 1 уравнение средней квадратичной
# регрессии 𝑥 на 𝑦

# %%
delta1 = sum((rv*sko/skoY*(sY-xBY)+xB-xBY)**2)/n
print('R2x =', round(delta1/dY,8))
vareps1 = (rv*sko/skoY*(sY-xBY)-sY)
print('Sε =', round((sum(vareps1**2)/(n-2))**0.5,8), 'sigma =', round(np.var(rv*sko/skoY*(sY-xBY)+xB-xBY)**0.5,8))
print('A =', round(sum(np.abs(vareps1/sY))/n,8))
# Out:
# R2x = 0.73225657
# Sε = 571.08082844 sigma = 168.719661
# A = 1.29979442

# %% [markdown]
# Данная модель регрессии объясняет 73%  дисперсии.
# Cредняя квадратическая ошибка больше  сигмы , значит использование модели регрессии нецелесообразно.
# A>7%, значит нельзя говорить о хорошем выборе модели.

# %% [markdown]
# 2 уравнение средней квадратичной
# регрессии у на x

# %%
delta2 = sum((rv*skoY/sko*(s-xB)+xBY-xB)**2)/n
print('R2y =', round(delta2/d,8))
vareps2 = (rv*skoY/sko*(s-xB)+xBY-s)
print('Sε =', round((sum(vareps2**2)/(n-2))**0.5,8), 'sigma =', round(np.var(rv*skoY/sko*(s-xB)+xBY)**0.5,8))
print('A =', round(sum(np.abs(vareps2/s))/n,8))
# Out:
# R2y = 0.5765978
# Sε = 99.52077679 sigma = 146.90384151
# A = 0.17708389

# %% [markdown]
# Данная модель регрессии объясняет 57%  дисперсии.
# Cредняя квадратическая ошибка меньше  сигмы , значит использование модели регрессии целесообразно.
# A>7%, значит нельзя говорить о хорошем выборе модели.

# %% [markdown]
# 3 уравнение  $y = -0.00021x^{2} + 1.125917x -32.361862$

# %%
delta3 = sum((B[2]*(np.array(s)**2)+B[1]*s+B[0]-xBY)**2)/n
print('R2y =', round(delta3/dY,8))
vareps3 = (B[2]*(np.array(s)**2)+B[1]*s+B[0]-np.array(sY))
print('Sε =', round((sum(vareps3**2)/(n-3))**0.5,8), 'sigma =', round(np.var(B[2]*(np.array(s)**2)+B[1]*s+B[0]-xBY)**0.5,8))
print('A =', round(sum(np.abs(vareps3/sY))/n,8))
# Out:
# R2y = 0.97474254
# Sε = 33.45539479 sigma = 203.88369867
# A = 0.04865379

# %% [markdown]
# Данная модель регрессии объясняет 97%  дисперсии.
# Cредняя квадратическая ошибка меньше  сигмы , значит использование модели регрессии целесообразно.
# A<7%, значит можно говорить о хорошем выборе модели.

# %% [markdown]
# 4 уравнение $y=\frac{x}{0.000041x+1.052909}$

# %%
delta4 = sum((s/(B_2[0]*s+B_2[1])-xBY)**2)/n
print('R2y =', round(delta4/dY,8))
vareps4 = (s/(B_2[0]*s+B_2[1]))-np.array(sY)
print('Sε =', round((sum(vareps4**2)/(n-2))**0.5,8), 'sigma =', round(np.var(s/(B_2[0]*s+B_2[1]))**0.5,8))
print('A =', round(sum(np.abs(vareps4/sY))/n,8))
# Out:
# R2y = 1.02329084
# Sε = 36.25662367 sigma = 208.78710136
# A = 0.04614522

# %% [markdown]
# Данная модель регрессии объясняет 100%  дисперсии.
# Cредняя квадратическая ошибка меньше  сигмы , значит использование модели регрессии целесообразно.
# A>7%, значит можно говорить о хорошем выборе модели.

# %% [markdown]
# ## Выводы
# В процессе выполнения данной практической работы были достигнуты поставленные задачи. В первую очередь, освоены основные понятия, связанные с корреляционной зависимостью между случайными величинами, статистическими гипотезами и проверкой их «справедливости». Произведено ознакомление с основными положениями метода наименьших квадратов, со статистическими свойствами МНК оценок, с понятием функции регрессии и роли МНК в регрессионном анализе, с корреляционным отношением, как мерой тесноты произвольной корреляционной связи.
